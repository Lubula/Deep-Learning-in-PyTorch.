# %%
# linear Algebra
v = [0,1]
import numpy as np

# %%
v = np.array([1,1])
print(v)
# Out:
# [1 1]

# %%
m = np.array([[1,1], [1,0]])
m
# Out:
# array([[1, 1],
#        [1, 0]])

# %%
import matplotlib.pyplot as plt
plt.xlim(0,3)
plt.ylim(0,3)

plt.arrow(0, 0, v[0], v[1], head_width=.1, head_length=.2)

# %%
np.sqrt(np.sum(v**2))
# Out:
# 1.4142135623730951

# %%
v = np.array ([0, 1, 1])
print(v)
# Out:
# [0 1 1]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.set_xlim([0, 3])
ax.set_ylim([0, 3])
ax.set_zlim([0, 3])

ax.quiver(0,0,0, v[0], v[1], v[2], length=1)

# %%
# Read up and study on:
# 1. basis vectors
# 2. basis change (common operation in machine learning and deep learning)

# %%
# matrix
M = np.array([[0, 1, 2], [1, 0, 2], [2, 1, 0]])
M
# Out:
# array([[0, 1, 2],
#        [1, 0, 2],
#        [2, 1, 0]])

# %%
M.shape
# Out:
# (3, 3)

# %%
M[0,0]
# Out:
# 0

# %%
M[:, 0]
# Out:
# array([0, 1, 2])

# %%
M[:2, :2]
# Out:
# array([[0, 1],
#        [1, 0]])

# %%
# linear regression
# predict tomorows temperature
# y (y hat) = wx + b

# %%
import pandas as pd
# read the data
df = pd.read_csv('clean_weather.csv')
#  see the data
df.head(5)
# Out:
#    Unnamed: 0  tmax  tmin  rain  tmax_tomorrow
# 0  1970-01-01  60.0  35.0   0.0           52.0
# 1  1970-01-02  52.0  39.0   0.0           52.0
# 2  1970-01-03  52.0  35.0   0.0           53.0
# 3  1970-01-04  53.0  36.0   0.0           52.0
# 4  1970-01-05  52.0  35.0   0.0           50.0

# %%
# tmax = max temperature, tmin = minimum temperature and tmax_tomorrow
# us tmax, tmin to pre
# y = w1x1 + w2x2 + w3x3 + b
w1 = .71
w2 = .3
w3 = .1
b = 10
w1 * 60 + w2 * 35 + w3 * 0 + b
# Out:
# 63.099999999999994

# %%
w = np.array ([w1, w2, w3])
x = np.array ([60, 35, 0])
np.dot(w, x) + b
# Out:
# 63.099999999999994

# %%
# matrix Multiplication
# check web link: https://i.sstatic.net/r2Sko.gif

# %%
# Learn about the normal equation method (please check mathematics for machine learning)
# gradient Descent
# matrix Inverse (Identity matrix)
# ridge regreession (reige regression matrix)
# force non linear combination of columns
# Understand the noraml Equation

# %%
df.head(5)
# Out:
#    Unnamed: 0  tmax  tmin  rain  tmax_tomorrow
# 0  1970-01-01  60.0  35.0   0.0           52.0
# 1  1970-01-02  52.0  39.0   0.0           52.0
# 2  1970-01-03  52.0  35.0   0.0           53.0
# 3  1970-01-04  53.0  36.0   0.0           52.0
# 4  1970-01-05  52.0  35.0   0.0           50.0

# %%
# Undeerstand broadcastings
# Understand derivatives
# Now create a regression model
